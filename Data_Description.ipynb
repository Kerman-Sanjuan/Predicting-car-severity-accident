# %% [markdown]
# # Coursera Final Capstone Report Week 1: Intruduction to Business Problem

# %%
import pandas as pd

# %% [markdown]
# ### 2. With the given dataset, describe the data.

# %%
data = pd.read_csv('US_Accidents_June20-1.csv',low_memory=False)

# %%
data.head()
# Out:
#     ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  ...  Roundabout Station   Stop  \
# 0  39.865147 -84.058723      NaN      NaN  ...       False   False  False
# 1  39.928059 -82.831184      NaN      NaN  ...       False   False  False
# 2  39.063148 -84.032608      NaN      NaN  ...       False   False  False
# 3  39.747753 -84.205582      NaN      NaN  ...       False   False  False
# 4  39.627781 -84.188354      NaN      NaN  ...       False   False  False
#
#   Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 0           False          False        False          Night          Night
# 1           False          False        False          Night          Night
# 2           False           True        False          Night          Night
# 3           False          False        False          Night            Day
# 4           False           True        False            Day            Day
#
#   Nautical_Twilight Astronomical_Twilight
# 0             Night                 Night
# 1             Night                   Day
# 2               Day                   Day
# 3               Day                   Day
# 4               Day                   Day
#
# [5 rows x 49 columns]

# %%
data.shape
# Out:
# (702748, 49)

# %% [markdown]
# So, this will be the data i will use to create all the report (Given dataset by Coursera). So, as we see, we have a bunch of data up here (exactly, 700K examples and 49 features).  As we see, there's a big quantity of data, but we will not use all of it, there some features which are not relevant to this certain problem, fo example, the incident certification and the rest of the id's.

# %%
data.describe()
# Out:
#                  TMC       Severity      Start_Lat      Start_Lng  End_Lat  \
# count  702748.000000  702748.000000  702748.000000  702748.000000      0.0
# mean      208.703712       2.354508      35.963056     -96.117496      NaN
# std        21.166518       0.485633       4.970068      17.711441      NaN
# min       200.000000       1.000000      24.568010    -124.458290      NaN
# 25%       201.000000       2.000000      32.840107    -117.832491      NaN
# 50%       201.000000       2.000000      34.858795     -93.746033      NaN
# 75%       201.000000       3.000000      40.103086     -81.347894      NaN
# max       406.000000       4.000000      48.999901     -68.060165      NaN
#
#        End_Lng   Distance(mi)         Number  Temperature(F)  Wind_Chill(F)  \
# count      0.0  702748.000000  258592.000000   692838.000000  248722.000000
# mean       NaN       0.124141    5146.753032       63.495052      51.093849
# std        NaN       1.195921    9194.276931       17.261841      22.131496
# min        NaN       0.000000       1.000000      -89.000000     -89.000000
# 25%        NaN       0.000000     748.000000       53.100000      34.000000
# 50%        NaN       0.000000    2466.000000       64.900000      53.000000
# 75%        NaN       0.010000    6599.000000       76.000000      69.000000
# max        NaN     251.220001  941747.000000      167.000000     111.000000
#
#          Humidity(%)   Pressure(in)  Visibility(mi)  Wind_Speed(mph)  \
# count  691858.000000  694999.000000   689424.000000    608081.000000
# mean       65.156203      29.815997        9.142800         8.508416
# std        21.856648       0.677985        2.345276         5.418588
# min         2.000000       0.120000        0.000000         0.000000
# 25%        49.000000      29.810000       10.000000         5.000000
# 50%        67.000000      29.960000       10.000000         8.000000
# 75%        83.000000      30.090000       10.000000        11.500000
# max       100.000000      33.040000      111.000000       822.800000
#
#        Precipitation(in)
# count      236759.000000
# mean            0.022676
# std             0.283712
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max            10.140000

# %% [markdown]
# For some reason, on this dataset are only stored information about low injuries or property damage severity, there's no data about serious injuries or fatalitys, so this is not the best dataset, but is the one who give us.

# %% [markdown]
# ### 2.1 Clean the data
